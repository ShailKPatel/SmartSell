# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the FSD train data
df = pd.read_csv('fsd_train_data.csv')

# Print the first 5 rows
print("Head of fsd_train_data.csv:")
print(df.head())

# Identify numeric and categorical columns
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

# Initialize a dictionary to store correlations
correlations = {}

# Compute Pearson correlation for numeric columns with FSD Theory
for col in numeric_cols:
    if col != 'FSD Theory':  # Exclude the target itself
        corr = df[col].corr(df['FSD Theory'])
        correlations[col] = corr

# Encode categorical columns for correlation
for col in categorical_cols:
    if col in ['Gender', 'Religion', 'Branch']:
        # One-hot encode categorical columns
        encoded = pd.get_dummies(df[col], prefix=col)
        for encoded_col in encoded.columns:
            corr = encoded[encoded_col].corr(df['FSD Theory'])
            correlations[encoded_col] = corr

# Convert Roll-1 to numeric and compute correlation
if 'Roll-1' in df.columns:
    corr = df['Roll-1'].astype(float).corr(df['FSD Theory'])
    correlations['Roll-1'] = corr

# Sort correlations by absolute value in descending order
sorted_correlations = dict(sorted(correlations.items(), key=lambda x: abs(x[1]), reverse=True))

# Print sorted correlations
print("\nCorrelations with FSD Theory (sorted by absolute value):")
for col, corr in sorted_correlations.items():
    print(f"{col}: {corr:.4f}")

# Prepare data for plotting
labels = list(sorted_correlations.keys())
values = list(sorted_correlations.values())

# Create a horizontal bar plot
plt.figure(figsize=(10, max(8, len(labels) * 0.4)))  # Adjust height based on number of features
plt.barh(labels[::-1], values[::-1], color=np.where(np.array(values[::-1]) >= 0, '#36A2EB', '#FF6384'))
plt.xlabel('Correlation Coefficient')
plt.ylabel('Features')
plt.title('Correlations with FSD Theory (Absolute Value Sorted)')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=0.5)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# Head of fsd_train_data.csv:
#   Gender Religion Branch  Roll-1  Roll-2  Roll-3  Math-1 Theory  \
# 0      M    Hindu     CE     350     288     176             47
# 1      F    Hindu    CST      18      23      16             84
# 2      F    Hindu   AIML      23       3       8             74
# 3      M    Hindu    CST     212     140      81             55
# 4      M    Hindu    CST     208     323     195             38
#
#    Physics Theory  Physics Practical  Java-1 Theory  ...  Java-1 Attendance  \
# 0              48                 75             50  ...              97.00
# 1              83                 81             61  ...              88.79
# 2              85                 86             64  ...              97.98
# 3              69                 82             56  ...              96.23
# 4              59                 74             36  ...              97.92
#
#    Software Engineering Attendance  Environmental Science Attendance  \
# 0                           100.00                            100.00
# 1                            94.29                            100.00
# 2                            92.31                             92.31
# 3                            96.97                            100.00
# 4                           100.00                            100.00
#
#    IOT Workshop Attendance  Math-2 Attendance  \
# 0                      100             100.00
# 1                      100              95.59
# 2                      100              93.55
# 3                      100             100.00
# 4                      100              91.80
#
#    Data Structures using Java Attendance  DBMS Attendance  \
# 0                                 100.00           100.00
# 1                                  95.16            93.44
# 2                                  96.61           100.00
# 3                                  97.01           100.00
# 4                                  93.33            90.28
#
#    Fundamental of Electronics and Electrical Attendance  Java-2 Attendance  \
# 0                                             100.00                100.00
# 1                                              92.45                 96.77
# 2                                             100.00                 96.88
# 3                                              96.00                100.00
# 4                                              92.00                 98.39
#
#    FSD Theory
# 0          84
# 1          87
# 2          93
# 3          81
# 4          48
#
# [5 rows x 37 columns]
#
# Correlations with FSD Theory (sorted by absolute value):
# Java-2 Theory: 0.7610
# DBMS Theory: 0.7423
# Roll-3: -0.7276
# Fundamental of Electronics and Electrical Theory: 0.6998
# Data Structures using Java Theory: 0.6958
# Physics Theory: 0.6851
# Software Engineering Theory: 0.6649
# DBMS Practical: 0.6620
# Java-1 Theory: 0.6589
# Math-2 Theory: 0.6562
# Math-1 Theory: 0.6235
# Data Structures using Java Practical: 0.5813
# Roll-2: -0.5768
# Java-2 Practical: 0.5760
# Fundamental of Electronics and Electrical Practical: 0.5324
# Environmental Science Theory: 0.4668
# Java-1 Practical: 0.4433
# Physics Practical: 0.3211
# Java-2 Attendance: 0.3087
# Data Structures using Java Attendance: 0.2954
# Branch_CSE: 0.2830
# Java-1 Attendance: 0.2715
# DBMS Attendance: 0.2670
# Fundamental of Electronics and Electrical Attendance: 0.2622
# Computer Workshop Practical: 0.2589
# IOT Workshop Practical: 0.2524
# Software Engineering Attendance: 0.2478
# Physics Attendance: 0.2434
# Roll-1: -0.2434
# Math-2 Attendance: 0.2416
# Math-1 Attendance: 0.2371
# Branch_CST: -0.1980
# Environmental Science Attendance: 0.1887
# Branch_RAI: -0.1521
# Software Engineering Practical: 0.1377
# Gender_F: 0.1359
# Gender_M: -0.1359
# Branch_AIDS: -0.1256
# Branch_CSD: -0.1056
# Branch_IT: 0.0951
# Branch_AIML: -0.0758
# Branch_CE: 0.0714
# Branch_CS&IT: -0.0688
# Branch_CEA: -0.0673
# Religion_Sikh: 0.0412
# IOT Workshop Attendance: -0.0240
# Religion_Jain: 0.0201
# Religion_Muslim: -0.0135
# Religion_Hindu: -0.0063
# Religion_Christian: -0.0034

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Ensure plots display inline in Jupyter Notebook
# %matplotlib inline

# Read the FSD train data
df = pd.read_csv('fsd_train_data.csv')

# Print the first 5 rows
print("Head of fsd_train_data.csv:")
print(df.head())

# Identify numeric and categorical columns
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

# Create a DataFrame for correlation calculations (including one-hot encoded categoricals)
df_encoded = df.copy()
for col in categorical_cols:
    if col in ['Gender', 'Religion', 'Branch']:
        encoded = pd.get_dummies(df[col], prefix=col)
        df_encoded = pd.concat([df_encoded, encoded], axis=1)
        df_encoded = df_encoded.drop(columns=[col])

# 1. Create dictionary of absolute correlations with FSD Theory
correlations_with_fsd = {}
for col in df_encoded.columns:
    if col != 'FSD Theory':  # Exclude the target itself
        corr = abs(df_encoded[col].corr(df_encoded['FSD Theory']))
        correlations_with_fsd[col] = corr

# Print the correlation dictionary (sorted by absolute value)
print("\nAbsolute correlations with FSD Theory:")
for col, corr in sorted(correlations_with_fsd.items(), key=lambda x: x[1], reverse=True):
    print(f"{col}: {corr:.4f}")

# 2. Compute pairwise correlations between all columns
corr_matrix = df_encoded.corr().abs()  # Absolute correlations

# Initialize list of columns to drop
columns_to_drop = []

# Check for pairs with correlation > 0.9
for i in range(len(corr_matrix.columns)):
    for j in range(i + 1, len(corr_matrix.columns)):
        col1 = corr_matrix.columns[i]
        col2 = corr_matrix.columns[j]
        if corr_matrix.iloc[i, j] > 0.9 and col1 != 'FSD Theory' and col2 != 'FSD Theory':
            # Compare correlations with FSD Theory
            corr1 = correlations_with_fsd.get(col1, 0)
            corr2 = correlations_with_fsd.get(col2, 0)
            # Drop the column with lower correlation with FSD Theory
            if corr1 < corr2:
                columns_to_drop.append(col1)
            else:
                columns_to_drop.append(col2)

# Remove duplicates from columns_to_drop
columns_to_drop = list(set(columns_to_drop))
print("\nColumns to drop due to high correlation (> 0.9):")
print(columns_to_drop if columns_to_drop else "No columns with correlation > 0.9")

# Create reduced DataFrame (optional, not saved unless needed)
df_reduced = df_encoded.drop(columns=columns_to_drop, errors='ignore')

# 3. Plot correlations as a bar plot
plt.figure(figsize=(12, 8))
bars = plt.barh(list(correlations_with_fsd.keys()), 
                [corr for corr in correlations_with_fsd.values()], 
                color='skyblue')
plt.xlabel('Absolute Correlation with FSD Theory')
plt.title('Correlation of Features with FSD Theory')
plt.tight_layout()

# Add correlation values on the bars
for bar, corr in zip(bars, correlations_with_fsd.values()):
    width = bar.get_width()
    plt.text(x=width + 0.01, y=bar.get_y() + bar.get_height()/2, s=f'{corr:.4f}', 
             ha='left', va='center')

# Display the plot in the notebook
plt.show()
# Out:
# Head of fsd_train_data.csv:
#   Gender Religion Branch  Roll-1  Roll-2  Roll-3  Math-1 Theory  \
# 0      M    Hindu     CE     350     288     176             47
# 1      F    Hindu    CST      18      23      16             84
# 2      F    Hindu   AIML      23       3       8             74
# 3      M    Hindu    CST     212     140      81             55
# 4      M    Hindu    CST     208     323     195             38
#
#    Physics Theory  Physics Practical  Java-1 Theory  ...  Java-1 Attendance  \
# 0              48                 75             50  ...              97.00
# 1              83                 81             61  ...              88.79
# 2              85                 86             64  ...              97.98
# 3              69                 82             56  ...              96.23
# 4              59                 74             36  ...              97.92
#
#    Software Engineering Attendance  Environmental Science Attendance  \
# 0                           100.00                            100.00
# 1                            94.29                            100.00
# 2                            92.31                             92.31
# 3                            96.97                            100.00
# 4                           100.00                            100.00
#
#    IOT Workshop Attendance  Math-2 Attendance  \
# 0                      100             100.00
# 1                      100              95.59
# 2                      100              93.55
# 3                      100             100.00
# 4                      100              91.80
#
#    Data Structures using Java Attendance  DBMS Attendance  \
# 0                                 100.00           100.00
# 1                                  95.16            93.44
# 2                                  96.61           100.00
# 3                                  97.01           100.00
# 4                                  93.33            90.28
#
#    Fundamental of Electronics and Electrical Attendance  Java-2 Attendance  \
# 0                                             100.00                100.00
# 1                                              92.45                 96.77
# 2                                             100.00                 96.88
# 3                                              96.00                100.00
# 4                                              92.00                 98.39
#
#    FSD Theory
# 0          84
# 1          87
# 2          93
# 3          81
# 4          48
#
# [5 rows x 37 columns]
#
# Absolute correlations with FSD Theory:
# Java-2 Theory: 0.7610
# DBMS Theory: 0.7423
# Roll-3: 0.7276
# Fundamental of Electronics and Electrical Theory: 0.6998
# Data Structures using Java Theory: 0.6958
# Physics Theory: 0.6851
# Software Engineering Theory: 0.6649
# DBMS Practical: 0.6620
# Java-1 Theory: 0.6589
# Math-2 Theory: 0.6562
# Math-1 Theory: 0.6235
# Data Structures using Java Practical: 0.5813
# Roll-2: 0.5768
# Java-2 Practical: 0.5760
# Fundamental of Electronics and Electrical Practical: 0.5324
# Environmental Science Theory: 0.4668
# Java-1 Practical: 0.4433
# Physics Practical: 0.3211
# Java-2 Attendance: 0.3087
# Data Structures using Java Attendance: 0.2954
# Branch_CSE: 0.2830
# Java-1 Attendance: 0.2715
# DBMS Attendance: 0.2670
# Fundamental of Electronics and Electrical Attendance: 0.2622
# Computer Workshop Practical: 0.2589
# IOT Workshop Practical: 0.2524
# Software Engineering Attendance: 0.2478
# Physics Attendance: 0.2434
# Roll-1: 0.2434
# Math-2 Attendance: 0.2416
# Math-1 Attendance: 0.2371
# Branch_CST: 0.1980
# Environmental Science Attendance: 0.1887
# Branch_RAI: 0.1521
# Software Engineering Practical: 0.1377
# Gender_F: 0.1359
# Gender_M: 0.1359
# Branch_AIDS: 0.1256
# Branch_CSD: 0.1056
# Branch_IT: 0.0951
# Branch_AIML: 0.0758
# Branch_CE: 0.0714
# Branch_CS&IT: 0.0688
# Branch_CEA: 0.0673
# Religion_Sikh: 0.0412
# IOT Workshop Attendance: 0.0240
# Religion_Jain: 0.0201
# Religion_Muslim: 0.0135
# Religion_Hindu: 0.0063
# Religion_Christian: 0.0034
#
# Columns to drop due to high correlation (> 0.9):
# ['Gender_M', 'Java-2 Practical']
